# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')

# %%
data = pd.read_csv('Final.csv')
data.head()
# Out:
#                                            Headlines  \
# 0                Object : Alcoholics Anonymous Badge
# 1  Every university 'needs' Alcoholics Anonymous ...
# 2   What happens in an Alcoholics Anonymous meeting?
# 3  The many groups that have copied Alcoholics An...
# 4                               Alcoholics Anonymous
#
#                                         Descriptions Authors  \
# 0  A History of the World is a partnership betwee...     NaN
# 1  Alcoholics Anonymous says the number of younge...     NaN
# 2  Members of Alcoholics Anonymous are marking it...     NaN
# 3  Alcoholics Anonymous was founded 80 years ago....     NaN
# 4                                                NaN     NaN
#
#              Published_Dates Publication  \
# 0                       None         NaN
# 1  2018-07-31 16:54:32+00:00    BBC News
# 2               10 June 2010    BBC News
# 3                9 June 2015    BBC News
# 4                       None         BBC
#
#                                             Articles category  \
# 0  The contributors father was a member of Alcoho...       {}
# 1  Image copyright Getty Images Alcoholics Anonym...       {}
# 2  Image caption The true nature of alcoholism is...       {}
# 3  Image copyright Other Image caption An AA meet...       {}
# 4                                                NaN       {}
#
#                                             Keywords  \
# 0  ['unless', 'content', 'views', 'anonymous', 'b...
# 1  ['student', 'really', 'anonymous', 'younger', ...
# 2  ['happens', 'anonymous', 'bad', 'group', 'meet...
# 3  ['copied', 'anonymous', 'steps', '12step', 'me...
# 4                        ['alcoholics', 'anonymous']
#
#                                            Summaries  \
# 0  The contributor's father was a member of Alcoh...
# 1  Image copyright Getty ImagesAlcoholics Anonymo...
# 2  Image caption The true nature of alcoholism is...
# 3  But Peter hasn't tasted alcohol in 34 years, a...
# 4                                                NaN
#
#                                          Source_URLs
# 0  http://www.bbc.co.uk/ahistoryoftheworld/object...
# 1   https://www.bbc.co.uk/news/amp/uk-wales-45023075
# 2                https://www.bbc.co.uk/news/10280806
# 3       https://www.bbc.co.uk/news/magazine-33049093
# 4  https://www.bbc.co.uk/programmes/topics/Alcoho...

# %%
print("Types and counts of stories", data.groupby(['Publication']).size())
# Out:
# Types and counts of stories Publication
# Ahmedabad Mirror                                                                            1
# BBC                                                                                       128
# BBC Cymru Fyw                                                                               2
# BBC News                                                                                  243
# BBC News Indonesia                                                                          2
# BBC News Mundo                                                                              1
# BBC News O'zbek                                                                             1
# BBC News Pidgin                                                                             1
# BBC News Tiáº¿ng Viá»‡t                                                                     1
# BBC News Ù�Ø§Ø±Ø³ÛŒ                                                                         1
# BBC News à¸šà¸µà¸šà¸µà¸‹à¸µà¹„à¸—à¸¢                                                        2
# BBC Sport                                                                                   4
# BBC Three                                                                                   5
# BBC è‹±ä¼¦ç½‘                                                                               3
# DailySun                                                                                    8
# Dealing with aggressive behavior in general practice & hospital | theindependentbd.com      1
# Deccan Chronicle                                                                           34
# Dhaka Tribune                                                                               1
# India Today                                                                                55
# Laughing out loud | theindependentbd.com                                                    1
# Mumbai Mirror                                                                              22
# The Daily Star                                                                              7
# Tribuneindia News Service                                                                  30
# https://www.hindustantimes.com/                                                            54
# dtype: int64

# %%
data.groupby(['Publication']).size().plot(kind='barh')

# %%
BBC = data[data["Publication"] == "BBC"]

# %%
import nltk

# Fill any blank fields
BBC.Headlines.fillna("", inplace=True)
BBC.Articles.fillna("", inplace=True)

# Join the Headlines and Articles
all_Articles = BBC.Headlines.str.cat(BBC.Articles, sep=' ')

# Tokenize. The NLTK tokenizer isn't awesome. Spacy has a nice one, but I don't think it is installed
words = nltk.word_tokenize(" ".join(all_Articles.tolist()))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5434: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
BBC.head()
# Out:
#                                             Headlines  \
# 4                                Alcoholics Anonymous
# 7               Witness History, Alcoholics Anonymous
# 12                               Alcoholics Anonymous
# 14                    AA: America's Gift to the World
# 17  Sally Pepper, Alcoholics Anonymous, Derby Coun...
#
#                                          Descriptions Authors Published_Dates  \
# 4                                                 NaN     NaN            None
# 7   In the summer of 1935 Alcoholics Anonymous was...     NaN            None
# 12  Get more of the music you love. Add tracks to ...     NaN            None
# 14  On the 80th birthday of Alcoholics Anonymous, ...     NaN            None
# 17  Sally learns what help is available for people...     NaN            None
#
#    Publication                                           Articles category  \
# 4          BBC                                                          {}
# 7          BBC  In the summer of 1935 the worlds most famous p...       {}
# 12         BBC                    Sign in to the BBC, or Register       {}
# 14         BBC  AL Kennedy tells the story of Alcoholics Anony...       {}
# 17         BBC  Recovering alcoholic Nicki chats with Sally ab...       {}
#
#                                              Keywords  \
# 4                         ['alcoholics', 'anonymous']
# 7   ['history', 'hulton', 'anonymous', 'pouring', ...
# 12  ['anonymous', 'register', 'alcoholics', 'bbc',...
# 14  ['gift', 'kennedy', 'tells', 'recovery', 'alco...
# 17  ['pepper', 'successful', 'football', 'does', '...
#
#                                             Summaries  \
# 4                                                 NaN
# 7   In the summer of 1935 the world's most famous ...
# 12                    Sign in to the BBC, or Register
# 14  AL Kennedy tells the story of Alcoholics Anony...
# 17  Recovering alcoholic Nicki chats with Sally ab...
#
#                                           Source_URLs
# 4   https://www.bbc.co.uk/programmes/topics/Alcoho...
# 7           https://www.bbc.co.uk/programmes/p01c7m2w
# 12          https://www.bbc.co.uk/music/tracks/n4hfh3
# 14          https://www.bbc.co.uk/programmes/b05pmrv0
# 17          https://www.bbc.co.uk/programmes/p02c4kvs

# %%
from nltk.corpus import stopwords
import string

# clearly more cleaning is needed here, but really I should get a better tokenizer
stop = stopwords.words('english') 
cleanwords = [i for i in words if i not in stop and i.isalpha() and len(i) > 2]

# %%
from wordcloud import WordCloud, STOPWORDS

wordcloud2 = WordCloud(
                          stopwords=STOPWORDS,
                          background_color='white',
                          width=1200,
                          height=1000
                         ).generate(" ".join(cleanwords))


plt.imshow(wordcloud2)
plt.axis('off')
plt.show()

# %%
# Bigrams should be more interesting

bigrams = nltk.bigrams(cleanwords)

# %%
# look at the most common. 

from collections import Counter

counter = Counter(bigrams)
print(counter.most_common(10))
# Out:
# [(('Alcoholics', 'Anonymous'), 93), (('Pete', 'Jackson'), 50), (('Love', 'Recovery'), 49), (('young', 'people'), 34), (('John', 'Hannah'), 29), (('Paul', 'Kaye'), 29), (('mental', 'health'), 29), (('Sue', 'Johnston'), 28), (('BBC', 'Radio'), 26), (('The', 'National'), 26)]

# %%
num_to_show = 30

labels = [" ".join(e[0]) for e in counter.most_common(num_to_show)]
values = [e[1] for e in counter.most_common(num_to_show)]

indexes = np.arange(len(labels))
width = 1

#plt.bar(indexes, values, width)
#plt.xticks(indexes + width * 0.5, labels, rotation=90)

plt.barh(indexes, values, width)
plt.yticks(indexes + width * 0.2, labels)
plt.show()
