# %% [markdown]
# ### Installing necessary packages
#
# - pip install -U gensim

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from gensim.scripts.glove2word2vec import glove2word2vec
from gensim.models import KeyedVectors # load the Stanford GloVe model

from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
stop = stopwords.words('english')

from textblob import TextBlob
from textblob import Word

import pandas as pd
import numpy as np
import re
# Out:
# C:\Users\GM\Anaconda3\lib\site-packages\smart_open\ssh.py:34: UserWarning: paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress
#   warnings.warn('paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress')
# C:\Users\GM\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %% [markdown]
# ### Reading the csv file and droping the Nan values and resetting index values

# %%
train = pd.read_csv('Final_AA_without_Nan.csv')
train.head()
# Out:
#                               Headlines  \
# 0                    BOOZE RUINS LIVES!
# 1      ALCOHOLICS, IT'S NEVER TOO LATE!
# 2               NO BOOZE FOR THESE TWO!
# 3                 A SEASON TO SOBER UP!
# 4  NAIR MAY GO FOR MENTAL HEALTH CHECK!
#
#                                         Descriptions       Authors  \
# 0  â€œTHE wake-up call for me should have been th...   Jabu Kumalo
# 1  IF YOU have a drinking problem or you know som...   Jabu Kumalo
# 2  SUNDAY was a joyful day as a husband and wife ...   Jabu Kumalo
# 3            MZANSI is known as a nation of boozers.  Sifiso Jimta
# 4  HE called President Cyril Ramaphosa the k-word...  Sun Reporter
#
#             Published_Dates Publication  \
# 0  2018-08-15T14:30:02.000Z    DailySun
# 1  2017-10-11T15:30:03.000Z    DailySun
# 2  2018-10-03T18:00:10.000Z    DailySun
# 3  2018-09-05T11:30:02.000Z    DailySun
# 4  2018-10-02T09:34:03.000Z    DailySun
#
#                                             Articles category  \
# 0  â€œTHE wake-up call for me should have been th...       {}
# 1  IF YOU have a drinking problem or you know som...       {}
# 2  SUNDAY was a joyful day as a husband and wife ...       {}
# 3  MZANSI is known as a nation of boozers.To give...       {}
# 4  HE called President Cyril Ramaphosa the k-word...       {}
#
#                                             Keywords  \
# 0  ['aa', 'booze', 'hit', 'lives', 'decided', 'in...
# 1  ['west', 'alcoholics', 'visit', 'thought', 'la...
# 2  ['anonymous', 'times', 'alcoholics', 'booze', ...
# 3  ['season', 'janet', 'soberspringchallenge', 'i...
# 4  ['surgeon', 'district', 'nairs', 'fort', 'napi...
#
#                                            Summaries  \
# 0  He told Daily Sun he sometimes couldnâ€™t beli...
# 1  IF YOU have a drinking problem or you know som...
# 2  SUNDAY was a joyful day as a husband and wife ...
# 3  The organisation has launched the #SoberSpring...
# 4  Govender argued that Nair should be treated as...
#
#                                          Source_URLs
# 0  https://www.dailysun.co.za/News/National/booze...
# 1  https://www.dailysun.co.za/News/National/alcoh...
# 2  https://www.dailysun.co.za/News/National/no-bo...
# 3  https://www.dailysun.co.za/News/National/a-sea...
# 4  https://www.dailysun.co.za/News/National/nair-...

# %% [markdown]
# ### Basic feature extraction using text data
# - Number of words
# - Number of characters
# - Average word length
# - Number of stopwords
# - Number of special characters
# - Number of numerics
# - Number of uppercase words

# %% [markdown]
# ### Number of words

# %%
train['word_count'] = train['Articles'].apply(lambda x: len(str(x).split(" ")))
train[['Articles','word_count']].head()
# Out:
#                                             Articles  word_count
# 0  â€œTHE wake-up call for me should have been th...         342
# 1  IF YOU have a drinking problem or you know som...         208
# 2  SUNDAY was a joyful day as a husband and wife ...         206
# 3  MZANSI is known as a nation of boozers.To give...         231
# 4  HE called President Cyril Ramaphosa the k-word...         398

# %% [markdown]
# ### Number of characters

# %%
train['char_count'] = train['Articles'].str.len() ## this also includes spaces
train[['Articles','char_count']].head()
# Out:
#                                             Articles  char_count
# 0  â€œTHE wake-up call for me should have been th...        1817
# 1  IF YOU have a drinking problem or you know som...        1144
# 2  SUNDAY was a joyful day as a husband and wife ...        1188
# 3  MZANSI is known as a nation of boozers.To give...        1426
# 4  HE called President Cyril Ramaphosa the k-word...        2599

# %% [markdown]
# ### Average word length

# %%
def avg_word(sentence):
    words = sentence.split()
    return (sum(len(word) for word in words)/len(words))

train['avg_word'] = train['Articles'].apply(lambda x: avg_word(x))
train[['Articles','avg_word']].head()
# Out:
#                                             Articles  avg_word
# 0  â€œTHE wake-up call for me should have been th...  4.315789
# 1  IF YOU have a drinking problem or you know som...  4.504808
# 2  SUNDAY was a joyful day as a husband and wife ...  4.771845
# 3  MZANSI is known as a nation of boozers.To give...  5.177489
# 4  HE called President Cyril Ramaphosa the k-word...  5.532663

# %% [markdown]
# ### Number of stopwords

# %%
train['stopwords'] = train['Articles'].apply(lambda x: len([x for x in x.split() if x in stop]))
train[['Articles','stopwords']].head()
# Out:
#                                             Articles  stopwords
# 0  â€œTHE wake-up call for me should have been th...        144
# 1  IF YOU have a drinking problem or you know som...         91
# 2  SUNDAY was a joyful day as a husband and wife ...         78
# 3  MZANSI is known as a nation of boozers.To give...         82
# 4  HE called President Cyril Ramaphosa the k-word...        175

# %% [markdown]
# ### Number of special characters

# %%
train['special_characters'] = train['Articles'].apply(lambda x: len([x for x in x.split() if x.startswith('#')]))
train[['Articles','special_characters']].head()
# Out:
#                                             Articles  special_characters
# 0  â€œTHE wake-up call for me should have been th...                   0
# 1  IF YOU have a drinking problem or you know som...                   0
# 2  SUNDAY was a joyful day as a husband and wife ...                   0
# 3  MZANSI is known as a nation of boozers.To give...                   3
# 4  HE called President Cyril Ramaphosa the k-word...                   0

# %% [markdown]
# ### Number of numerics

# %%
train['numerics'] = train['Articles'].apply(lambda x: len([x for x in x.split() if x.isdigit()]))
train[['Articles','numerics']].head()
# Out:
#                                             Articles  numerics
# 0  â€œTHE wake-up call for me should have been th...         2
# 1  IF YOU have a drinking problem or you know som...         4
# 2  SUNDAY was a joyful day as a husband and wife ...         7
# 3  MZANSI is known as a nation of boozers.To give...         1
# 4  HE called President Cyril Ramaphosa the k-word...         2

# %% [markdown]
# ### Number of uppercase words

# %%
train['upper'] = train['Articles'].apply(lambda x: len([x for x in x.split() if x.isupper()]))
train[['Articles','upper']].head()
# Out:
#                                             Articles  upper
# 0  â€œTHE wake-up call for me should have been th...     12
# 1  IF YOU have a drinking problem or you know som...      9
# 2  SUNDAY was a joyful day as a husband and wife ...      1
# 3  MZANSI is known as a nation of boozers.To give...      6
# 4  HE called President Cyril Ramaphosa the k-word...      1

# %% [markdown]
# ### Basic Text Pre-processing of text data
# - Lower casing
# - Punctuation removal
# - Stopwords removal
# - Frequent words removal
# - Rare words removal
# - Spelling correction
# - Tokenization
# - Stemming
# - Lemmatization

# %% [markdown]
# ### Lower casing

# %%
train['Articles'] = train['Articles'].apply(lambda x: " ".join(x.lower() for x in x.split()))
train['Articles'].head()
# Out:
# 0    â€œthe wake-up call for me should have been th...
# 1    if you have a drinking problem or you know som...
# 2    sunday was a joyful day as a husband and wife ...
# 3    mzansi is known as a nation of boozers.to give...
# 4    he called president cyril ramaphosa the k-word...
# Name: Articles, dtype: object

# %% [markdown]
# ### Punctuation removal

# %%
train['Articles'] = train['Articles'].str.replace('[^\w\s]','')
train['Articles'].head()
# Out:
# 0    âœthe wakeup call for me should have been the ...
# 1    if you have a drinking problem or you know som...
# 2    sunday was a joyful day as a husband and wife ...
# 3    mzansi is known as a nation of boozersto give ...
# 4    he called president cyril ramaphosa the kword ...
# Name: Articles, dtype: object

# %% [markdown]
# ### Stopwords removal

# %%
train['Articles'] = train['Articles'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
train['Articles'].head()
# Out:
# 0    âœthe wakeup call day bullet blew hat offâ wor...
# 1    drinking problem know somebody uncle tomâs hal...
# 2    sunday joyful day husband wife soweto shared s...
# 3    mzansi known nation boozersto give boozing day...
# 4    called president cyril ramaphosa kword widely ...
# Name: Articles, dtype: object

# %% [markdown]
# ### Common word removal

# %%
freq = pd.Series(' '.join(train['Articles']).split()).value_counts()[:10]
freq
# Out:
# said          110
# alcohol        85
# â              82
# one            80
# aa             69
# anonymous      68
# alcoholics     66
# drinking       62
# years          58
# would          55
# dtype: int64

# %%
freq = list(freq.index)
train['Articles'] = train['Articles'].apply(lambda x: " ".join(x for x in x.split() if x not in freq))
train['Articles'].head()
# Out:
# 0    âœthe wakeup call day bullet blew hat offâ wor...
# 1    problem know somebody uncle tomâs hall orlando...
# 2    sunday joyful day husband wife soweto shared s...
# 3    mzansi known nation boozersto give boozing day...
# 4    called president cyril ramaphosa kword widely ...
# Name: Articles, dtype: object

# %% [markdown]
# ### Rare words removal

# %%
freq = pd.Series(' '.join(train['Articles']).split()).value_counts()[-10:]
freq
# Out:
# stems             1
# holierthanthou    1
# âcasio            1
# azhar             1
# simon             1
# memories          1
# fakes             1
# cameron           1
# usingâ            1
# âkiller           1
# dtype: int64

# %%
freq = list(freq.index)
train['Articles'] = train['Articles'].apply(lambda x: " ".join(x for x in x.split() if x not in freq))
train['Articles'].head()
# Out:
# 0    âœthe wakeup call day bullet blew hat offâ wor...
# 1    problem know somebody uncle tomâs hall orlando...
# 2    sunday joyful day husband wife soweto shared s...
# 3    mzansi known nation boozersto give boozing day...
# 4    called president cyril ramaphosa kword widely ...
# Name: Articles, dtype: object

# %% [markdown]
# ### Spelling correction

# %%
train['Articles'][:5].apply(lambda x: str(TextBlob(x).correct()))
# Out:
# 0    the wake call day bullet blew hat off words mu...
# 1    problem know somebody uncle tombs hall orlando...
# 2    sunday joyful day husband wife sowed shared st...
# 3    means known nation boozersto give oozing days ...
# 4    called president cyril ramaphosa word widely c...
# Name: Articles, dtype: object

# %% [markdown]
# ### Tokenization

# %%
TextBlob(train['Articles'][1]).words
# Out:
# WordList(['problem', 'know', 'somebody', 'uncle', 'tomâs', 'hall', 'orlando', 'west', 'soweto', 'best', 'place', 'saturdaythe', 'soweto', 'group', 'holding', '35th', 'annual', 'rally', 'members', 'community', 'invited', 'hear', 'pulled', 'pit', 'uncontrollable', 'imbizo', 'starts', '9am', 'aims', 'reach', 'people', 'booze', 'problema', 'member', 'group', 'imbizo', 'highlight', 'year', 'sober', '20', 'yearshe', 'told', 'peopleâs', 'paper', 'âœi', 'never', 'missed', 'imbizo', 'since', 'stopped', 'joined', 'group', 'time', 'thought', 'everything', 'finished', 'thought', 'life', 'reached', 'dead', 'end', 'things', 'bad', 'even', 'attempted', 'suicide', 'three', 'times', 'see', 'successfulâœtoday', 'always', 'enthusiastic', 'ready', 'face', 'lifeâhe', 'never', 'knew', 'problem', 'doctor', 'suggested', 'visit', 'support', 'group', 'emphasised', 'never', 'late', 'stopentrance', 'imbizo', 'freethe', 'group', 'reached', '0861', '435', '722', 'nationally'])

# %% [markdown]
# ### Stemming

# %%
st = PorterStemmer()
train['Articles'][:5].apply(lambda x: " ".join([st.stem(word) for word in x.split()]))
# Out:
# 0    âœthe wakeup call day bullet blew hat offâ wor...
# 1    problem know somebodi uncl tomâ hall orlando w...
# 2    sunday joy day husband wife soweto share stori...
# 3    mzansi known nation boozersto give booz day le...
# 4    call presid cyril ramaphosa kword wide circul ...
# Name: Articles, dtype: object

# %% [markdown]
# ### Lemmatization

# %%
train['Articles'] = train['Articles'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
train['Articles'].head()
# Out:
# 0    âœthe wakeup call day bullet blew hat offâ wor...
# 1    problem know somebody uncle tomâs hall orlando...
# 2    sunday joyful day husband wife soweto shared s...
# 3    mzansi known nation boozersto give boozing day...
# 4    called president cyril ramaphosa kword widely ...
# Name: Articles, dtype: object

# %% [markdown]
# ### Advance Text Processing
# - N-grams
# - Term Frequency
# - Inverse Document Frequency
# - Term Frequency-Inverse Document Frequency (TF-IDF)
# - Bag of Words
# - Sentiment Analysis
# - Word Embedding

# %% [markdown]
# ### N-grams

# %%
TextBlob(train['Articles'][0]).ngrams(2)
# Out:
# [WordList(['âœthe', 'wakeup']),
#  WordList(['wakeup', 'call']),
#  WordList(['call', 'day']),
#  WordList(['day', 'bullet']),
#  WordList(['bullet', 'blew']),
#  WordList(['blew', 'hat']),
#  WordList(['hat', 'offâ']),
#  WordList(['offâ', 'word']),
#  WordList(['word', 'mussolini']),
#  WordList(['mussolini', 'shumi']),
#  WordList(['shumi', 'managed']),
#  WordList(['managed', 'stop']),
#  WordList(['stop', 'thanks']),
#  WordList(['thanks', 'told']),
#  WordList(['told', 'daily']),
#  WordList(['daily', 'sun']),
#  WordList(['sun', 'sometimes']),
#  WordList(['sometimes', 'couldnât']),
#  WordList(['couldnât', 'believe']),
#  WordList(['believe', 'still']),
#  WordList(['still', 'alive']),
#  WordList(['alive', 'criminal']),
#  WordList(['criminal', 'activity']),
#  WordList(['activity', 'involved']),
#  WordList(['involved', 'speaking']),
#  WordList(['speaking', 'day']),
#  WordList(['day', 'almost']),
#  WordList(['almost', 'lost']),
#  WordList(['lost', 'life']),
#  WordList(['life', 'mussolini']),
#  WordList(['mussolini', 'âœwe']),
#  WordList(['âœwe', 'coming']),
#  WordList(['coming', 'back']),
#  WordList(['back', 'soccer']),
#  WordList(['soccer', 'match']),
#  WordList(['match', 'chief']),
#  WordList(['chief', 'sundown']),
#  WordList(['sundown', 'decided']),
#  WordList(['decided', 'rob']),
#  WordList(['rob', 'guy']),
#  WordList(['guy', 'âœthere']),
#  WordList(['âœthere', 'four']),
#  WordList(['four', 'u']),
#  WordList(['u', 'thought']),
#  WordList(['thought', 'easy']),
#  WordList(['easy', 'target']),
#  WordList(['target', 'woman']),
#  WordList(['woman', 'âœas']),
#  WordList(['âœas', 'tried']),
#  WordList(['tried', 'grab']),
#  WordList(['grab', 'pulled']),
#  WordList(['pulled', 'gun']),
#  WordList(['gun', 'fired']),
#  WordList(['fired', 'u']),
#  WordList(['u', 'first']),
#  WordList(['first', 'bullet']),
#  WordList(['bullet', 'hit']),
#  WordList(['hit', 'friend']),
#  WordList(['friend', 'severely']),
#  WordList(['severely', 'injured']),
#  WordList(['injured', 'âœwe']),
#  WordList(['âœwe', 'scattered']),
#  WordList(['scattered', 'place']),
#  WordList(['place', 'kept']),
#  WordList(['kept', 'shooting']),
#  WordList(['shooting', 'felt']),
#  WordList(['felt', 'hat']),
#  WordList(['hat', 'leaving']),
#  WordList(['leaving', 'head']),
#  WordList(['head', 'hit']),
#  WordList(['hit', 'bullet']),
#  WordList(['bullet', 'âœevery']),
#  WordList(['âœevery', 'time']),
#  WordList(['time', 'think']),
#  WordList(['think', 'moment']),
#  WordList(['moment', 'sweat']),
#  WordList(['sweat', 'bitâ']),
#  WordList(['bitâ', 'mussolini']),
#  WordList(['mussolini', 'later']),
#  WordList(['later', 'learned']),
#  WordList(['learned', 'man']),
#  WordList(['man', 'soldier']),
#  WordList(['soldier', 'thanks']),
#  WordList(['thanks', 'happy']),
#  WordList(['happy', 'say']),
#  WordList(['say', 'longer']),
#  WordList(['longer', 'lived']),
#  WordList(['lived', 'rough']),
#  WordList(['rough', 'dangerous']),
#  WordList(['dangerous', 'life']),
#  WordList(['life', 'show']),
#  WordList(['show', 'gratitude']),
#  WordList(['gratitude', 'mussolini']),
#  WordList(['mussolini', 'member']),
#  WordList(['member', 'group']),
#  WordList(['group', 'katlehong']),
#  WordList(['katlehong', 'ekurhuleni']),
#  WordList(['ekurhuleni', 'holding']),
#  WordList(['holding', 'rally']),
#  WordList(['rally', 'saturday']),
#  WordList(['saturday', 'aim']),
#  WordList(['aim', 'imbizo']),
#  WordList(['imbizo', 'spread']),
#  WordList(['spread', 'message']),
#  WordList(['message', 'still']),
#  WordList(['still', 'ruled']),
#  WordList(['ruled', 'hope']),
#  WordList(['hope', 'imbizo']),
#  WordList(['imbizo', 'held']),
#  WordList(['held', 'tsolo']),
#  WordList(['tsolo', 'hall']),
#  WordList(['hall', 'makau']),
#  WordList(['makau', 'street']),
#  WordList(['street', '9am']),
#  WordList(['9am', 'venue']),
#  WordList(['venue', 'close']),
#  WordList(['close', 'wellknown']),
#  WordList(['wellknown', 'change']),
#  WordList(['change', 'bible']),
#  WordList(['bible', 'church']),
#  WordList(['church', 'mussolini']),
#  WordList(['mussolini', 'sober']),
#  WordList(['sober', '10']),
#  WordList(['10', 'âœafter']),
#  WordList(['âœafter', 'involved']),
#  WordList(['involved', 'two']),
#  WordList(['two', 'car']),
#  WordList(['car', 'accident']),
#  WordList(['accident', 'driving']),
#  WordList(['driving', 'company']),
#  WordList(['company', 'car']),
#  WordList(['car', 'knew']),
#  WordList(['knew', 'needed']),
#  WordList(['needed', 'help']),
#  WordList(['help', 'die']),
#  WordList(['die', 'âœi']),
#  WordList(['âœi', 'decided']),
#  WordList(['decided', 'tell']),
#  WordList(['tell', 'employer']),
#  WordList(['employer', 'truth']),
#  WordList(['truth', 'booked']),
#  WordList(['booked', 'rehab']),
#  WordList(['rehab', 'came']),
#  WordList(['came', 'joined']),
#  WordList(['joined', 'past']),
#  WordList(['past', '10']),
#  WordList(['10', 'pure']),
#  WordList(['pure', 'blissâmussolini']),
#  WordList(['blissâmussolini', 'anyone']),
#  WordList(['anyone', 'think']),
#  WordList(['think', 'might']),
#  WordList(['might', 'problem']),
#  WordList(['problem', 'attend']),
#  WordList(['attend', 'event']),
#  WordList(['event', 'find']),
#  WordList(['find', 'solution'])]

# %% [markdown]
# ### Term Frequency

# %%
tf1 = (train['Articles'][1:2]).apply(lambda x: pd.value_counts(x.split(" "))).sum(axis = 0).reset_index()
tf1.columns = ['words','tf']
tf1
# Out:
#                 words  tf
# 0               group   5
# 1              imbizo   4
# 2               never   3
# 3              member   2
# 4                time   2
# 5              soweto   2
# 6             problem   2
# 7             thought   2
# 8             reached   2
# 9               place   1
# 10           finished   1
# 11              sober   1
# 12               face   1
# 13        saturdaythe   1
# 14             doctor   1
# 15           problema   1
# 16              rally   1
# 17              reach   1
# 18                âœi   1
# 19         emphasised   1
# 20              three   1
# 21               knew   1
# 22             always   1
# 23  successfulâœtoday   1
# 24               dead   1
# 25             annual   1
# 26            lifeâhe   1
# 27               hear   1
# 28                pit   1
# 29             pulled   1
# ..                ...  ..
# 50                aim   1
# 51               even   1
# 52            holding   1
# 53     uncontrollable   1
# 54         everything   1
# 55               0861   1
# 56            yearshe   1
# 57         nationally   1
# 58          community   1
# 59               west   1
# 60              uncle   1
# 61       stopentrance   1
# 62               know   1
# 63              booze   1
# 64                see   1
# 65             joined   1
# 66              thing   1
# 67              ready   1
# 68               life   1
# 69              tomâs   1
# 70            support   1
# 71          attempted   1
# 72            suicide   1
# 73               late   1
# 74                722   1
# 75            orlando   1
# 76                435   1
# 77                 20   1
# 78                end   1
# 79              visit   1
#
# [80 rows x 2 columns]

# %% [markdown]
# ### Inverse Document Frequency

# %%
for i,word in enumerate(tf1['words']):
    tf1.loc[i, 'idf'] = np.log(train.shape[0]/(len(train[train['Articles'].str.contains(word)])))
tf1
# Out:
#                 words  tf       idf
# 0               group   5  1.044545
# 1              imbizo   4  2.890372
# 2               never   3  1.424035
# 3              member   2  0.897942
# 4                time   2  0.378066
# 5              soweto   2  3.295837
# 6             problem   2  1.044545
# 7             thought   2  1.791759
# 8             reached   2  2.379546
# 9               place   1  1.504077
# 10           finished   1  3.988984
# 11              sober   1  1.280934
# 12               face   1  1.155771
# 13        saturdaythe   1  3.988984
# 14             doctor   1  2.379546
# 15           problema   1  3.988984
# 16              rally   1  2.043074
# 17              reach   1  2.197225
# 18                âœi   1  0.993252
# 19         emphasised   1  2.890372
# 20              three   1  1.155771
# 21               knew   1  2.043074
# 22             always   1  1.686399
# 23  successfulâœtoday   1  3.988984
# 24               dead   1  1.909543
# 25             annual   1  2.602690
# 26            lifeâhe   1  3.988984
# 27               hear   1  1.098612
# 28                pit   1  1.349927
# 29             pulled   1  2.602690
# ..                ...  ..       ...
# 50                aim   1  0.993252
# 51               even   1  0.587787
# 52            holding   1  2.379546
# 53     uncontrollable   1  3.988984
# 54         everything   1  2.602690
# 55               0861   1  3.295837
# 56            yearshe   1  3.988984
# 57         nationally   1  3.295837
# 58          community   1  2.197225
# 59               west   1  2.043074
# 60              uncle   1  2.602690
# 61       stopentrance   1  3.988984
# 62               know   1  0.587787
# 63              booze   1  2.197225
# 64                see   1  0.810930
# 65             joined   1  2.602690
# 66              thing   1  0.693147
# 67              ready   1  1.791759
# 68               life   1  0.770108
# 69              tomâs   1  3.295837
# 70            support   1  1.791759
# 71          attempted   1  3.988984
# 72            suicide   1  2.602690
# 73               late   1  0.730888
# 74                722   1  3.295837
# 75            orlando   1  2.890372
# 76                435   1  3.988984
# 77                 20   1  0.730888
# 78                end   1  0.300105
# 79              visit   1  1.909543
#
# [80 rows x 3 columns]

# %% [markdown]
# ### Term Frequency – Inverse Document Frequency (TF-IDF)

# %%
tf1['tfidf'] = tf1['tf'] * tf1['idf']
tf1
# Out:
#                 words  tf       idf      tfidf
# 0               group   5  1.044545   5.222725
# 1              imbizo   4  2.890372  11.561487
# 2               never   3  1.424035   4.272104
# 3              member   2  0.897942   1.795883
# 4                time   2  0.378066   0.756132
# 5              soweto   2  3.295837   6.591674
# 6             problem   2  1.044545   2.089090
# 7             thought   2  1.791759   3.583519
# 8             reached   2  2.379546   4.759092
# 9               place   1  1.504077   1.504077
# 10           finished   1  3.988984   3.988984
# 11              sober   1  1.280934   1.280934
# 12               face   1  1.155771   1.155771
# 13        saturdaythe   1  3.988984   3.988984
# 14             doctor   1  2.379546   2.379546
# 15           problema   1  3.988984   3.988984
# 16              rally   1  2.043074   2.043074
# 17              reach   1  2.197225   2.197225
# 18                âœi   1  0.993252   0.993252
# 19         emphasised   1  2.890372   2.890372
# 20              three   1  1.155771   1.155771
# 21               knew   1  2.043074   2.043074
# 22             always   1  1.686399   1.686399
# 23  successfulâœtoday   1  3.988984   3.988984
# 24               dead   1  1.909543   1.909543
# 25             annual   1  2.602690   2.602690
# 26            lifeâhe   1  3.988984   3.988984
# 27               hear   1  1.098612   1.098612
# 28                pit   1  1.349927   1.349927
# 29             pulled   1  2.602690   2.602690
# ..                ...  ..       ...        ...
# 50                aim   1  0.993252   0.993252
# 51               even   1  0.587787   0.587787
# 52            holding   1  2.379546   2.379546
# 53     uncontrollable   1  3.988984   3.988984
# 54         everything   1  2.602690   2.602690
# 55               0861   1  3.295837   3.295837
# 56            yearshe   1  3.988984   3.988984
# 57         nationally   1  3.295837   3.295837
# 58          community   1  2.197225   2.197225
# 59               west   1  2.043074   2.043074
# 60              uncle   1  2.602690   2.602690
# 61       stopentrance   1  3.988984   3.988984
# 62               know   1  0.587787   0.587787
# 63              booze   1  2.197225   2.197225
# 64                see   1  0.810930   0.810930
# 65             joined   1  2.602690   2.602690
# 66              thing   1  0.693147   0.693147
# 67              ready   1  1.791759   1.791759
# 68               life   1  0.770108   0.770108
# 69              tomâs   1  3.295837   3.295837
# 70            support   1  1.791759   1.791759
# 71          attempted   1  3.988984   3.988984
# 72            suicide   1  2.602690   2.602690
# 73               late   1  0.730888   0.730888
# 74                722   1  3.295837   3.295837
# 75            orlando   1  2.890372   2.890372
# 76                435   1  3.988984   3.988984
# 77                 20   1  0.730888   0.730888
# 78                end   1  0.300105   0.300105
# 79              visit   1  1.909543   1.909543
#
# [80 rows x 4 columns]

# %%
tfidf = TfidfVectorizer(max_features=1000, lowercase=True, analyzer='word',
 stop_words= 'english',ngram_range=(1,1))
train_vect = tfidf.fit_transform(train['Articles'])

train_vect
# Out:
# <54x1000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 4980 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ### Bag of Words

# %%
bow = CountVectorizer(max_features=1000, lowercase=True, ngram_range=(1,1),analyzer = "word")
train_bow = bow.fit_transform(train['Articles'])
train_bow
# Out:
# <54x1000 sparse matrix of type '<class 'numpy.int64'>'
# 	with 5646 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ### Sentiment Analysis

# %%
train['Articles'][:5].apply(lambda x: TextBlob(x).sentiment)
# Out:
# 0     (0.06317460317460317, 0.3844444444444445)
# 1      (0.1642857142857143, 0.5095238095238096)
# 2      (0.23636363636363633, 0.303030303030303)
# 3     (0.13974358974358975, 0.5596153846153846)
# 4    (-0.04444444444444443, 0.3074074074074075)
# Name: Articles, dtype: object

# %%
train['sentiment'] = train['Articles'].apply(lambda x: TextBlob(x).sentiment[0] )
train[['Articles','sentiment']].head()
# Out:
#                                             Articles  sentiment
# 0  âœthe wakeup call day bullet blew hat offâ wor...   0.063175
# 1  problem know somebody uncle tomâs hall orlando...   0.164286
# 2  sunday joyful day husband wife soweto shared s...   0.236364
# 3  mzansi known nation boozersto give boozing day...   0.139744
# 4  called president cyril ramaphosa kword widely ...  -0.044444

# %% [markdown]
# ### Word Embeddings

# %%
glove_input_file = 'glove.6B.100d.txt'
word2vec_output_file = 'glove.6B.100d.txt.word2vec'
glove2word2vec(glove_input_file, word2vec_output_file)
# Out:
# (400000, 100)

# %%
filename = 'glove.6B.100d.txt.word2vec'
model = KeyedVectors.load_word2vec_format(filename, binary=False)

# %%
model['go']
# Out:
# array([-0.078894,  0.4616  ,  0.57779 , -0.71637 , -0.13121 ,  0.4186  ,
#        -0.29156 ,  0.52006 ,  0.089986, -0.35062 ,  0.51755 ,  0.51998 ,
#         0.15218 ,  0.41485 , -0.12377 , -0.37222 ,  0.0273  ,  0.75673 ,
#        -0.8739  ,  0.58935 ,  0.46662 ,  0.62918 ,  0.092603, -0.012868,
#        -0.015169,  0.25567 , -0.43025 , -0.77668 ,  0.71449 , -0.3834  ,
#        -0.69638 ,  0.23522 ,  0.11396 ,  0.02778 ,  0.071357,  0.87409 ,
#        -0.1281  ,  0.063576,  0.067867, -0.50181 , -0.28523 , -0.072536,
#        -0.50738 , -0.6914  , -0.53579 , -0.11361 , -0.38234 , -0.12414 ,
#         0.011214, -1.1622  ,  0.037057, -0.18495 ,  0.01416 ,  0.87193 ,
#        -0.097309, -2.3565  , -0.14554 ,  0.28275 ,  2.0053  ,  0.23439 ,
#        -0.38298 ,  0.69539 , -0.44916 , -0.094157,  0.90527 ,  0.65764 ,
#         0.27628 ,  0.30688 , -0.57781 , -0.22987 , -0.083043, -0.57236 ,
#        -0.299   , -0.81112 ,  0.039752, -0.05681 , -0.48879 , -0.18091 ,
#        -0.28152 , -0.20559 ,  0.4932  , -0.033999, -0.53139 , -0.28297 ,
#        -1.4475  , -0.18685 ,  0.091177,  0.11454 , -0.28168 , -0.33565 ,
#        -0.31663 , -0.1089  ,  0.10111 , -0.23737 , -0.64955 , -0.268   ,
#         0.35096 ,  0.26352 ,  0.59397 ,  0.26741 ], dtype=float32)

# %%
model['away']
# Out:
# array([-0.10379 , -0.014792,  0.59933 , -0.51316 , -0.036463,  0.6588  ,
#        -0.57906 ,  0.17819 ,  0.23663 , -0.21384 ,  0.55339 ,  0.53597 ,
#         0.041444,  0.16095 ,  0.017093, -0.37242 ,  0.017974,  0.39268 ,
#        -0.23265 ,  0.1818  ,  0.66405 ,  0.98163 ,  0.42339 ,  0.030581,
#         0.35015 ,  0.25519 , -0.71182 , -0.42184 ,  0.13068 , -0.47452 ,
#        -0.08175 ,  0.1574  , -0.13262 ,  0.22679 , -0.16885 , -0.11122 ,
#        -0.32272 , -0.020978, -0.43345 ,  0.172   , -0.67366 , -0.79052 ,
#         0.10556 , -0.4219  , -0.12385 , -0.063486, -0.17843 ,  0.56359 ,
#         0.16986 , -0.17804 ,  0.13956 , -0.20169 ,  0.078985,  1.4497  ,
#         0.23556 , -2.6014  , -0.5286  , -0.11636 ,  1.7184  ,  0.33254 ,
#         0.12136 ,  1.1602  , -0.2914  ,  0.47125 ,  0.41869 ,  0.35271 ,
#         0.47869 , -0.042281, -0.18294 ,  0.1796  , -0.24431 , -0.34042 ,
#         0.20337 , -0.93676 ,  0.013077,  0.080339, -0.36604 , -0.44005 ,
#        -0.35393 ,  0.15907 ,  0.55807 ,  0.1492  , -0.86433 ,  0.040305,
#        -1.0939  , -0.26386 , -0.29494 ,  0.25696 , -0.33718 , -0.086468,
#        -0.24246 , -0.21114 ,  0.099632,  0.12815 , -0.78714 , -0.51785 ,
#        -0.10944 ,  0.9763  ,  0.57032 ,  0.13581 ], dtype=float32)

# %%
(model['go'] + model['away'])/2
# Out:
# array([-0.091342  ,  0.223404  ,  0.58856   , -0.614765  , -0.0838365 ,
#         0.5387    , -0.43531   ,  0.349125  ,  0.163308  , -0.28223   ,
#         0.53547   ,  0.52797496,  0.096812  ,  0.2879    , -0.0533385 ,
#        -0.37232   ,  0.022637  ,  0.574705  , -0.553275  ,  0.385575  ,
#         0.565335  ,  0.805405  ,  0.2579965 ,  0.0088565 ,  0.1674905 ,
#         0.25543   , -0.571035  , -0.59926   ,  0.422585  , -0.42896   ,
#        -0.389065  ,  0.19631   , -0.00933   ,  0.127285  , -0.0487465 ,
#         0.381435  , -0.22540998,  0.021299  , -0.1827915 , -0.16490501,
#        -0.47944498, -0.431528  , -0.20091   , -0.55665   , -0.32982   ,
#        -0.088548  , -0.28038502,  0.219725  ,  0.090537  , -0.67012   ,
#         0.0883085 , -0.19332   ,  0.0465725 ,  1.160815  ,  0.0691255 ,
#        -2.47895   , -0.33707   ,  0.083195  ,  1.86185   ,  0.283465  ,
#        -0.13081   ,  0.927795  , -0.37028   ,  0.1885465 ,  0.66198   ,
#         0.505175  ,  0.37748498,  0.1322995 , -0.380375  , -0.025135  ,
#        -0.1636765 , -0.45639   , -0.047815  , -0.87394   ,  0.0264145 ,
#         0.0117645 , -0.427415  , -0.31048   , -0.317725  , -0.02326   ,
#         0.525635  ,  0.05760051, -0.69786   , -0.1213325 , -1.2707    ,
#        -0.225355  , -0.1018815 ,  0.18575001, -0.30943   , -0.211059  ,
#        -0.279545  , -0.16002001,  0.100371  , -0.05461   , -0.71834505,
#        -0.392925  ,  0.12075999,  0.61991   ,  0.582145  ,  0.20161   ],
#       dtype=float32)
