# %% [markdown]
# ## The Hindu Sentiment Analysis
# ### Installing necessary python packages

# %% [markdown]
# !pip install pandas
# !pip install vaderSentiment

# %% [markdown]
# ### Importing the installed Libraries

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import pandas as pd
import re

# %% [markdown]
# ### Reading The Hindu AA News Dataset and droping the missing values & some columns from the dataset.

# %%
data = pd.read_csv('The_Hindu.csv')
data = data.drop(['Headlines', 'Descriptions', 'Authors', 'Published_Dates', 'Source_URLs'], axis=1).dropna().reset_index(drop=True)
data.head()
# Out:
#                                             Articles
# 0  RELIGIONRamayanam: Akkaraikeni Srinidhi, Sri R...
# 1  RELIGIONSelva Vinayagar Temple:Chitra Pournami...
# 2  TIRUNELVELIAlcoholics Anonymous and Al-Anon:Re...
# 3  RELIGIONSelva Vinayagar Temple: Chitra Pournam...
# 4  RELIGIONSelva Vinayagar Temple:Pradosha puja, ...

# %% [markdown]
# ### cleaning each article

# %%
cleaning = re.compile(r"[.;:!\'?,\"()\[\]](<br\s*/><br\s*/>)|(\-)|(\/)")

data['Cleaned_Articles'] = [cleaning.sub("", data['Articles'][i].lower().replace('\r\n\r\n', ' ').replace("\'", "")) for i in range(len(data['Articles']))]

data = data.drop(['Articles'], axis=1)
data.head()
# Out:
#                                     Cleaned_Articles
# 0  religionramayanam: akkaraikeni srinidhi, sri r...
# 1  religionselva vinayagar temple:chitra pournami...
# 2  tirunelvelialcoholics anonymous and alanon:reg...
# 3  religionselva vinayagar temple: chitra pournam...
# 4  religionselva vinayagar temple:pradosha puja, ...

# %% [markdown]
# ### For each article calculating the Polarity values of the following
# * Positive
# * Neutral
# * Negative
# * Compound

# %%
analyser = SentimentIntensityAnalyzer()

data['polarity'] = [analyser.polarity_scores(data['Cleaned_Articles'][i]) for i in range(len(data['Cleaned_Articles']))]

# %%
display(data)
# Out:
#                                         Cleaned_Articles  \
# 0      religionramayanam: akkaraikeni srinidhi, sri r...
# 1      religionselva vinayagar temple:chitra pournami...
# 2      tirunelvelialcoholics anonymous and alanon:reg...
# 3      religionselva vinayagar temple: chitra pournam...
# 4      religionselva vinayagar temple:pradosha puja, ...
# 5      tirunelvelialcoholics anonymous and alanon:reg...
# 6      religionramayanam: akkaraikeni srinidhi, sri r...
# 7      religionramayanam: akkaraikeni srinidhi, sri r...
# 8      religionselva vinayagar temple:discourse on ‘t...
# 9      tirunelvelialcoholics anonymous and alanon:reg...
# 10     religionselva vinayagar temple: discourse on ‘...
# 11     religionramayanam: somasundaram, sri balakrish...
# 12     religionselva vinayagar temple:discourse on ‘s...
# 13     religionramayanam:vidya venkataraman, sri ragh...
# 14     religionselva vinayagar temple:panchangam read...
'neg': 0.0, 'neu': 0.818, 'pos': 0.182, 'comp...
# 6      {'neg': 0.0, 'neu': 0.948, 'pos': 0.052, 'comp...
# 7      {'neg': 0.0, 'neu': 0.93, 'pos': 0.07, 'compou...
# 8      {'neg': 0.018, 'neu': 0.97, 'pos': 0.013, 'com...
# 9      {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 10     {'neg': 0.015, 'neu': 0.959, 'pos': 0.025, 'co...
# 11     {'neg': 0.0, 'neu': 0.956, 'pos': 0.044, 'comp...
# 12     {'neg': 0.0, 'neu': 0.955, 'pos': 0.045, 'comp...
# 13     {'neg': 0.005, 'neu': 0.939, 'pos': 0.056, 'co...
# 14     {'neg': 0.0, 'neu': 0.965, 'pos': 0.035, 'comp...
# 15     {'neg': 0.0, 'neu': 0.96, 'pos': 0.04, 'compou...
# 16     {'neg': 0.0, 'neu': 0.966, 'pos': 0.034, 'comp...
# 17     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 18     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 19     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 20     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 21     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 22     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 23     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 24     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 25     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 26     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 27     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 28     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 29     {'neg': 0.0, 'neu': 0.879, 'pos': 0.121, 'comp...
# ...                                                  ...
# 11812  {'neg': 0.006, 'neu': 0.956, 'pos': 0.037, 'co...
# 11813  {'neg': 0.0, 'neu': 0.961, 'pos': 0.039, 'comp...
# 11814  {'neg': 0.026, 'neu': 0.924, 'pos': 0.05, 'com...
# 11815  {'neg': 0.0, 'neu': 0.974, 'pos': 0.026, 'comp...
# 11816  {'neg': 0.0, 'neu': 0.923, 'pos': 0.077, 'comp...
# 11817  {'neg': 0.0, 'neu': 0.948, 'pos': 0.052, 'comp...
# 11818  {'neg': 0.004, 'neu': 0.959, 'pos': 0.037, 'co...
# 11819  {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'comp...
# 11820  {'neg': 0.0, 'neu': 0.934, 'pos': 0.066, 'comp...
# 11821  {'neg': 0.0, 'neu': 0.964, 'pos': 0.036, 'comp...
# 11822  {'neg': 0.0, 'neu': 0.953, 'pos': 0.047, 'comp...
# 11823  {'neg': 0.0, 'neu': 0.947, 'pos': 0.053, 'comp...
# 11824  {'neg': 0.044, 'neu': 0.888, 'pos': 0.067, 'co...
# 11825  {'neg': 0.0, 'neu': 0.973, 'pos': 0.027, 'comp...
# 11826  {'neg': 0.009, 'neu': 0.929, 'pos': 0.062, 'co...
# 11827  {'neg': 0.006, 'neu': 0.923, 'pos': 0.07, 'com...
# 11828  {'neg': 0.0, 'neu': 0.973, 'pos': 0.027, 'comp...
# 11829  {'neg': 0.0, 'neu': 0.945, 'pos': 0.055, 'comp...
# 11830  {'neg': 0.006, 'neu': 0.883, 'pos': 0.112, 'co...
# 11831  {'neg': 0.0, 'neu': 0.935, 'pos': 0.065, 'comp...
# 11832  {'neg': 0.006, 'neu': 0.883, 'pos': 0.112, 'co...
# 11833  {'neg': 0.0, 'neu': 0.935, 'pos': 0.065, 'comp...
# 11834  {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'comp...
# 11835  {'neg': 0.0, 'neu': 0.939, 'pos': 0.061, 'comp...
# 11836  {'neg': 0.0, 'neu': 0.924, 'pos': 0.076, 'comp...
# 11837  {'neg': 0.0, 'neu': 0.926, 'pos': 0.074, 'comp...
# 11838  {'neg': 0.046, 'neu': 0.954, 'pos': 0.0, 'comp...
# 11839  {'neg': 0.0, 'neu': 0.922, 'pos': 0.078, 'comp...
# 11840  {'neg': 0.007, 'neu': 0.965, 'pos': 0.028, 'co...
# 11841  {'neg': 0.0, 'neu': 0.932, 'pos': 0.068, 'comp...
#
# [11842 rows x 2 columns]

# %%
data.shape
# Out:
# (11842, 2)
