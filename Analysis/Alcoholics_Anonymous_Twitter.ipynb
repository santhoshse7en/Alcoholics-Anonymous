# %% [markdown]
# ### tweety - Python Package to access the Twitter database without API
#
# - pip install tweety

# %%
from twitter.tweety import tweets

# %% [markdown]
# ### Parse argument of specific Twitter keyword. In our case its 'Alcoholics Anonymous'

# %%
tweety = tweets('Alcoholics Anonymous')
# Out:
# calculating time  151  seconds taken to parse all the tweets from twitter
# total tweets are : 703

# %% [markdown]
# tweety directory

# %%
print(dir(tweety))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'final_sentiment_scores', 'tweets', 'tweets_df']

# %% [markdown]
# Alcoholics Anonymous related tweets DataFrame include Polarity Scores

# %%
tweety.tweets_df
# Out:
#                                                 tweets sentiment  \
# 0    Alcoholics Anonymous ??? Connecticut Area 11 h...   neutral
# 1    “Everyone has problems. Getting drunk won't so...  positive
# 2    STEP 6 .A..A. Alcoholics Anonymous pic.twitter...   neutral
# 3    "Suppose we fall short of the chosen ideal and...  positive
# 4    *at Alcoholics Anonymous* me: hi, my name is k...  negative
# 5    Lol. Only Frank Gallagher would call Alcoholic...  positive
# 6    Alcoholics Anonymous : Daily Reflection http:/...   neutral
# 7    chairing my first meeting of alcoholics anonym...  positive
# 8    Alcoholics Anonymous : Find Local A.A. http://...   neutral
# 9            Alcoholics Anonymous but for Raptors fans   neutral
# 10   .A.A. STEP 6 Alcoholics Anonymous Another awes...  positive
# 11   Alcoholics Anonymous - AA - http://healthfinde...   neutral
# 12   Alcoholics anonymous | Etsy http://densimetrik...   neutral
# ...

# %% [markdown]
# Final Sentiment Score for all tweets related to 'Alcoholics_Anonymous'

# %%
tweety.final_sentiment_scores
# Out:
# {'neu': 0.85, 'neg': 0.058, 'pos': 0.093, 'compound': 0.0}
