# %% [markdown]
# ## BBC Sentiment Analysis
# ### Installing necessary python packages

# %% [markdown]
# !pip install pandas
# !pip install vaderSentiment

# %% [markdown]
# ### Importing the installed Libraries

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import pandas as pd
import re

# %% [markdown]
# ### Reading The Economic Times AA News Dataset and droping the missing values & some columns from the dataset.

# %%
data = pd.read_csv('The_Economic_Times.csv')
data = data.drop(['Headlines', 'Descriptions', 'Authors', 'Published_Dates', 'Summaries', 'Keywords'], axis=1).dropna().reset_index(drop=True)
data.head()
# Out:
#                                             Articles
# 0  Food ministry seeks delay in ethanol blending ...
# 1  In a head-to-head evaluation of the Alcoholics...
# 2  What's so great about living for the day? Or f...
# 3  Can Alcoholics Anonymous (AA) be turned into a...
# 4  Alcoholics Anonymous, the community that helps...

# %% [markdown]
# ### cleaning each article

# %%
cleaning = re.compile(r"[.;:!\'?,\"()\[\]](<br\s*/><br\s*/>)|(\-)|(\/)")

data['Cleaned_Articles'] = [cleaning.sub("", data['Articles'][i].lower().replace('\r\n\r\n', ' ').replace("\'", "")) for i in range(len(data['Articles']))]

data = data.drop(['Articles'], axis=1)
data.head()
# Out:
#                                     Cleaned_Articles
# 0  food ministry seeks delay in ethanol blending ...
# 1  in a headtohead evaluation of the alcoholics a...
# 2  whats so great about living for the day? or fo...
# 3  can alcoholics anonymous (aa) be turned into a...
# 4  alcoholics anonymous, the community that helps...

# %% [markdown]
# ### For each article calculating the Polarity values of the following
# * Positive
# * Neutral
# * Negative
# * Compound

# %%
analyser = SentimentIntensityAnalyzer()

data['polarity'] = [analyser.polarity_scores(data['Cleaned_Articles'][i]) for i in range(len(data['Cleaned_Articles']))]

# %%
display(data)
# Out:
#                                      Cleaned_Articles  \
# 0   food ministry seeks delay in ethanol blending ...
# 1   in a headtohead evaluation of the alcoholics a...
# 2   whats so great about living for the day? or fo...
# 3   can alcoholics anonymous (aa) be turned into a...
# 4   alcoholics anonymous, the community that helps...
# 5   when celebrities chug more than they can handl...
# 6   aphorisms telling us to live ���one day at a t...
# 7   turbulent personal life = topperforming pro cr...
# 8   a friend who attended a workshop of overeaters...
# 9   sitting here, in an undisclosed location 502 m...
# 10  it’s a number like any other. yet, twelve has ...
# 11  tiger woods has now ‘rediscovered’ his childho...
# 12  another story by priyadarshan with a goodforno...
# 13  if you’re 27 and reading this, and you think i...
# 14  she wakes up around 5.45 in the morning. she n...
# 15  washington: teenagers who have their first dri...
# 16  knowledge management is a bi**h. nobody knows ...
# 17  it has been three years since the right of chi...
# 18  ‘the lost blend is an o.henry story about two ...
# 19  if you consider yourself a friend, why this ov...
# 20  paper currency had always been alluring for th...
# 21  new york: on may 11, an anonymous buyer at chr...
# 22  not without its traces of amusement, a certain...
# 23  why do sports teams cheat? 31 mar, 2018, 03.56...
# 24  new delhi : “india wine insider 2017”, the fir...
# 25  the average price of a kingfisher quart (large...
# 26  mumbai: bollywood super star salman khan may f...
# 27  a year ago, before the investor lawsuits and t...
# 28  the latest: indiana senate approves hate crime...
# 29  india testing a new way to deal with stray cat...
# 30  sharechat takes down half a million pieces of ...
# 31  loreal heiress francoise bettencourts love for...
# 32  loreal heiress francoise bettencourts love for...
# 33  murli manohar joshi seeks ec probe into circul...
# 34  roger mcnamees zucked asks facebook users, sta...
# 35  new delhibhopal: the dean of a jabalpur medica...
# 36  times group wins big at abby awards 13 apr, 20...
# 37  updated: apr 20, 2019, 06.18 pm ist the good n...
# 38  apples latest ipad, buy or wait? 21 apr, 2017,...
# 39  women in sesaipura return from a village meeti...
# 40  ​ parties use innovative ways to bribe voters ...
# 41  shop while youre drunk: why amazon feels like ...
# 42  new delhi: restaurants, hotels and eateries sh...
# 43  no surprise here. kingfisher airline’s stock f...
# 44  jet airways passengers bleed midair after crew...
# 45  tribal eviction: no intervention or survey til...
# 46  cash, booze and gold: india seizures surge com...
# 47  pune: the food and drugs administration has ro...
# 48  directors report the directors have pleasure i...
# 49  accept the updated privacy & cookie policy dea...
# 50  gandhi was delivering the keynote address at a...
# 51  image for representation only. credit: getty o...
# 52  make notes, eat healthy & exercise daily: 7 wa...
# 53  the it department posted on its website, few d...
# 54  union minister of science and technology harsh...
#
#                                              polarity
# 0   {'neg': 0.038, 'neu': 0.892, 'pos': 0.07, 'com...
# 1   {'neg': 0.04, 'neu': 0.791, 'pos': 0.169, 'com...
# 2   {'neg': 0.043, 'neu': 0.851, 'pos': 0.106, 'co...
# 3   {'neg': 0.046, 'neu': 0.861, 'pos': 0.092, 'co...
# 4   {'neg': 0.047, 'neu': 0.732, 'pos': 0.221, 'co...
# 5   {'neg': 0.145, 'neu': 0.766, 'pos': 0.089, 'co...
# 6   {'neg': 0.06, 'neu': 0.849, 'pos': 0.091, 'com...
# 7   {'neg': 0.116, 'neu': 0.797, 'pos': 0.088, 'co...
# 8   {'neg': 0.067, 'neu': 0.848, 'pos': 0.085, 'co...
# 9   {'neg': 0.084, 'neu': 0.813, 'pos': 0.103, 'co...
# 10  {'neg': 0.019, 'neu': 0.897, 'pos': 0.084, 'co...
# 11  {'neg': 0.089, 'neu': 0.776, 'pos': 0.135, 'co...
# 12  {'neg': 0.0, 'neu': 0.809, 'pos': 0.191, 'comp...
# 13  {'neg': 0.0, 'neu': 0.927, 'pos': 0.073, 'comp...
# 14  {'neg': 0.062, 'neu': 0.805, 'pos': 0.132, 'co...
# 15  {'neg': 0.052, 'neu': 0.931, 'pos': 0.017, 'co...
# 16  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 17  {'neg': 0.0, 'neu': 0.842, 'pos': 0.158, 'comp...
# 18  {'neg': 0.097, 'neu': 0.832, 'pos': 0.071, 'co...
# 19  {'neg': 0.119, 'neu': 0.544, 'pos': 0.336, 'co...
# 20  {'neg': 0.221, 'neu': 0.779, 'pos': 0.0, 'comp...
# 21  {'neg': 0.01, 'neu': 0.896, 'pos': 0.094, 'com...
# 22  {'neg': 0.025, 'neu': 0.878, 'pos': 0.097, 'co...
# 23  {'neg': 0.088, 'neu': 0.62, 'pos': 0.292, 'com...
# 24  {'neg': 0.015, 'neu': 0.845, 'pos': 0.14, 'com...
# 25  {'neg': 0.023, 'neu': 0.923, 'pos': 0.054, 'co...
# 26  {'neg': 0.09, 'neu': 0.765, 'pos': 0.145, 'com...
# 27  {'neg': 0.092, 'neu': 0.846, 'pos': 0.062, 'co...
# 28  {'neg': 0.075, 'neu': 0.832, 'pos': 0.093, 'co...
# 29  {'neg': 0.15, 'neu': 0.841, 'pos': 0.009, 'com...
# 30  {'neg': 0.069, 'neu': 0.851, 'pos': 0.08, 'com...
# 31  {'neg': 0.044, 'neu': 0.859, 'pos': 0.097, 'co...
# 32  {'neg': 0.128, 'neu': 0.785, 'pos': 0.087, 'co...
# 33  {'neg': 0.098, 'neu': 0.85, 'pos': 0.052, 'com...
# 34  {'neg': 0.084, 'neu': 0.86, 'pos': 0.056, 'com...
# 35  {'neg': 0.129, 'neu': 0.856, 'pos': 0.015, 'co...
# 36  {'neg': 0.014, 'neu': 0.784, 'pos': 0.202, 'co...
# 37  {'neg': 0.055, 'neu': 0.775, 'pos': 0.17, 'com...
# 38  {'neg': 0.072, 'neu': 0.865, 'pos': 0.063, 'co...
# 39  {'neg': 0.035, 'neu': 0.915, 'pos': 0.05, 'com...
# 40  {'neg': 0.12, 'neu': 0.797, 'pos': 0.084, 'com...
# 41  {'neg': 0.109, 'neu': 0.814, 'pos': 0.076, 'co...
# 42  {'neg': 0.02, 'neu': 0.902, 'pos': 0.079, 'com...
# 43  {'neg': 0.096, 'neu': 0.83, 'pos': 0.074, 'com...
# 44  {'neg': 0.159, 'neu': 0.814, 'pos': 0.027, 'co...
# 45  {'neg': 0.092, 'neu': 0.88, 'pos': 0.027, 'com...
# 46  {'neg': 0.081, 'neu': 0.83, 'pos': 0.09, 'comp...
# 47  {'neg': 0.0, 'neu': 0.857, 'pos': 0.143, 'comp...
# 48  {'neg': 0.032, 'neu': 0.878, 'pos': 0.091, 'co...
# 49  {'neg': 0.025, 'neu': 0.743, 'pos': 0.231, 'co...
# 50  {'neg': 0.058, 'neu': 0.889, 'pos': 0.053, 'co...
# 51  {'neg': 0.025, 'neu': 0.849, 'pos': 0.126, 'co...
# 52  {'neg': 0.15, 'neu': 0.74, 'pos': 0.111, 'comp...
# 53  {'neg': 0.025, 'neu': 0.975, 'pos': 0.0, 'comp...
# 54  {'neg': 0.026, 'neu': 0.885, 'pos': 0.089, 'co...

# %%
data.shape
# Out:
# (55, 2)
