# %% [markdown]
# ## The Tribune Sentiment Analysis
# ### Installing necessary python packages

# %% [markdown]
# !pip install pandas
# !pip install vaderSentiment

# %% [markdown]
# ### Importing the installed Libraries

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import pandas as pd
import re

# %% [markdown]
# ### Reading The Tribune AA News Dataset and droping the missing values & some columns from the dataset.

# %%
data = pd.read_csv('The_Tribune.csv')
data = data.drop(['Headlines', 'Descriptions', 'Authors', 'Published_Dates', 'Summaries', 'Keywords'], axis=1).dropna().reset_index(drop=True)
data.head()
# Out:
#                                             Articles
# 0  Chandigarh, August 8There is a hope for hopele...
# 1  Linda Chhakchhuak\rToday, globally India shows...
# 2  Pradeep SharmaHow about a life beyond Patiala ...
# 3  Lakhinder Jit Singh Vohra\rAAP MP Bhagwant Man...
# 4  Tribune News ServicePanchkula, May 21The Alcoh...

# %% [markdown]
# ### cleaning each article

# %%
cleaning = re.compile(r"[.;:!\'?,\"()\[\]](<br\s*/><br\s*/>)|(\-)|(\/)")

data['Cleaned_Articles'] = [cleaning.sub("", data['Articles'][i].lower().replace('\r\n\r\n', ' ').replace("\'", "")) for i in range(len(data['Articles']))]

data = data.drop(['Articles'], axis=1)
data.head()
# Out:
#                                     Cleaned_Articles
# 0  chandigarh, august 8there is a hope for hopele...
# 1  linda chhakchhuak\rtoday, globally india shows...
# 2  pradeep sharmahow about a life beyond patiala ...
# 3  lakhinder jit singh vohra\raap mp bhagwant man...
# 4  tribune news servicepanchkula, may 21the alcoh...

# %% [markdown]
# ### For each article calculating the Polarity values of the following
# * Positive
# * Neutral
# * Negative
# * Compound

# %%
analyser = SentimentIntensityAnalyzer()

data['polarity'] = [analyser.polarity_scores(data['Cleaned_Articles'][i]) for i in range(len(data['Cleaned_Articles']))]

# %%
display(data)
# Out:
#                                      Cleaned_Articles  \
# 0   chandigarh, august 8there is a hope for hopele...
# 1   linda chhakchhuak\rtoday, globally india shows...
# 2   pradeep sharmahow about a life beyond patiala ...
# 3   lakhinder jit singh vohra\raap mp bhagwant man...
# 4   tribune news servicepanchkula, may 21the alcoh...
# 5   chandigarh, july 30\rexperts and practitioners...
# 6   the picturesque resort along the gushing water...
# 7   mona\rgod, grant me the serenity, to accept th...
# 8   los angeles, march 17demi lovato has opened up...
# 9   panaji, january 13facing flak both nationally ...
# 10  baltimore (usa), december 20\rolympic swimming...
# 11  new delhi, july 12 \rthe indian air force (iaf...
# 12  actorfilmmaker mel gibson has claimed he has b...
# 13  volunteers of the red cross unit of ssd girls ...
# 14  rajendra p jindal\rtwo different news, apparen...
# 15  jupinderjit singhtribune news servicechandigar...
# 16  tribune news servicechandigarh, july 10\rthe o...
# 17  bamako, december 13 \rseveral dozen civilians ...
# 18  new delhi, june 5\ran iranian studying at jnu ...
# 19  thane, may 25 a businessman from ulhasnagar he...
# 20  washington, november 13amazon has decided to s...
# 21  ishfaq tantrytribune news servicesrinagar, feb...
# 22  tribune news servicepanipat, september 29a sus...
# 23  paris, april 4   a massive leak of 11.5 millio...
# 24  chandigarh, december 14\rthe district consumer...
# 25  our correspondentabohar, february 13the court ...
# 26  panchkula: the deployment of paramilitary forc...
# 27  tribune news servicechandigarh, december 3\rju...
# 28  london, may 13 experts have been working round...
# 29  tribune news serviceshimla, december 8\rclose ...
# 30  paris, december 13\rcristiano ronaldo capped a...
# 31  in his avatar as a futurologist, henry kissing...
# 32  islamabadkarachi, april 19a looming supreme co...
# 33  mona\rwhat would you rather choose—chase a wom...
#
#                                              polarity
# 0   {'neg': 0.065, 'neu': 0.821, 'pos': 0.115, 'co...
# 1   {'neg': 0.105, 'neu': 0.788, 'pos': 0.107, 'co...
# 2   {'neg': 0.047, 'neu': 0.877, 'pos': 0.076, 'co...
# 3   {'neg': 0.112, 'neu': 0.799, 'pos': 0.089, 'co...
# 4   {'neg': 0.061, 'neu': 0.788, 'pos': 0.151, 'co...
# 5   {'neg': 0.024, 'neu': 0.845, 'pos': 0.131, 'co...
# 6   {'neg': 0.134, 'neu': 0.757, 'pos': 0.109, 'co...
# 7   {'neg': 0.068, 'neu': 0.805, 'pos': 0.127, 'co...
# 8   {'neg': 0.038, 'neu': 0.838, 'pos': 0.123, 'co...
# 9   {'neg': 0.013, 'neu': 0.934, 'pos': 0.053, 'co...
# 10  {'neg': 0.069, 'neu': 0.825, 'pos': 0.106, 'co...
# 11  {'neg': 0.06, 'neu': 0.901, 'pos': 0.039, 'com...
# 12  {'neg': 0.084, 'neu': 0.851, 'pos': 0.065, 'co...
# 13  {'neg': 0.02, 'neu': 0.904, 'pos': 0.076, 'com...
# 14  {'neg': 0.111, 'neu': 0.809, 'pos': 0.079, 'co...
# 15  {'neg': 0.153, 'neu': 0.785, 'pos': 0.063, 'co...
# 16  {'neg': 0.048, 'neu': 0.896, 'pos': 0.056, 'co...
# 17  {'neg': 0.157, 'neu': 0.815, 'pos': 0.028, 'co...
# 18  {'neg': 0.076, 'neu': 0.869, 'pos': 0.055, 'co...
# 19  {'neg': 0.074, 'neu': 0.91, 'pos': 0.017, 'com...
# 20  {'neg': 0.033, 'neu': 0.917, 'pos': 0.05, 'com...
# 21  {'neg': 0.029, 'neu': 0.933, 'pos': 0.039, 'co...
# 22  {'neg': 0.138, 'neu': 0.828, 'pos': 0.035, 'co...
# 23  {'neg': 0.036, 'neu': 0.923, 'pos': 0.041, 'co...
# 24  {'neg': 0.086, 'neu': 0.866, 'pos': 0.048, 'co...
# 25  {'neg': 0.144, 'neu': 0.797, 'pos': 0.059, 'co...
# 26  {'neg': 0.096, 'neu': 0.89, 'pos': 0.013, 'com...
# 27  {'neg': 0.031, 'neu': 0.863, 'pos': 0.106, 'co...
# 28  {'neg': 0.139, 'neu': 0.786, 'pos': 0.075, 'co...
# 29  {'neg': 0.053, 'neu': 0.9, 'pos': 0.046, 'comp...
# 30  {'neg': 0.084, 'neu': 0.752, 'pos': 0.164, 'co...
# 31  {'neg': 0.034, 'neu': 0.878, 'pos': 0.088, 'co...
# 32  {'neg': 0.079, 'neu': 0.792, 'pos': 0.129, 'co...
# 33  {'neg': 0.075, 'neu': 0.777, 'pos': 0.149, 'co...

# %%
data.shape
# Out:
# (34, 2)
