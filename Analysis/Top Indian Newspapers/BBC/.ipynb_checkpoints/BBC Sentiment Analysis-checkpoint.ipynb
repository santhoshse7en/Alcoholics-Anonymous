# %% [markdown]
# ## BBC Sentiment Analysis
# ### Installing necessary python packages

# %% [markdown]
# !pip install pandas
# !pip install vaderSentiment

# %% [markdown]
# ### Importing the installed Libraries

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import pandas as pd
import re

# %% [markdown]
# ### Reading BBC AA News Dataset and droping the missing values & some columns from the dataset.

# %%
data = pd.read_csv('BBC.csv')
data = data.drop(['Headlines', 'Descriptions', 'Authors', 'Published_Dates', 'Source_URLs', 'Summaries', 'Keywords'], axis=1).dropna().reset_index(drop=True)
data.head()
# Out:
#                                             Articles
# 0  Image copyright Getty Images\r\n\r\nAlcoholics...
# 1  Image caption The true nature of alcoholism is...
# 2  Image copyright Other Image caption An AA meet...
# 3  Image copyright Greg Doherty / Getty Images Im...
# 4  Image copyright Thinkstock\r\n\r\nEverybody th...

# %% [markdown]
# ### cleaning each article

# %%
cleaning = re.compile(r"[.;:!\'?,\"()\[\]](<br\s*/><br\s*/>)|(\-)|(\/)")

data['Cleaned_Articles'] = [cleaning.sub("", data['Articles'][i].lower().replace('\r\n\r\n', ' ').replace("\'", "")) for i in range(len(data['Articles']))]

data = data.drop(['Articles'], axis=1)
data.head()
# Out:
#                                     Cleaned_Articles
# 0  image copyright getty images alcoholics anonym...
# 1  image caption the true nature of alcoholism is...
# 2  image copyright other image caption an aa meet...
# 3  image copyright greg doherty  getty images ima...
# 4  image copyright thinkstock everybody thinks th...

# %% [markdown]
# ### For each article calculating the Polarity values of the following
# * Positive
# * Neutral
# * Negative
# * Compound

# %%
analyser = SentimentIntensityAnalyzer()

data['polarity'] = [analyser.polarity_scores(data['Cleaned_Articles'][i]) for i in range(len(data['Cleaned_Articles']))]

# %%
display(data)
# Out:
#                                       Cleaned_Articles  \
# 0    image copyright getty images alcoholics anonym...
# 1    image caption the true nature of alcoholism is...
# 2    image copyright other image caption an aa meet...
# 3    image copyright greg doherty  getty images ima...
# 4    image copyright thinkstock everybody thinks th...
# 5                      sign in to the bbc, or register
# 6    the contributors father was a member of alcoho...
# 7    a woman has pleaded guilty to being almost eig...
# 8    video a growing number of young people are see...
# 9    in the summer of 1935 the worlds most famous p...
# 10   newsbeat has been given rare access to an anon...
# 11   a competitive and snobby exbanker tries to com...
# 12   josie d’arby discovers the amazing story of ho...
# 13   recovering alcoholic nicki chats with sally ab...
# 14   third series of the awardnominated comedy dram...
# 15   al kennedy tells the story of alcoholics anony...
# 16   fiona has a problem she thinks only danno can ...
# 17        other podcasts you may like see all podcasts
# 18   image copyright vik kainth some ethnic minorit...
# 19   it is christmas eve at alcoholics anonymous, a...
# 20   for millions of alcoholics around the world, a...
# 21   on demand this programme is not currently avai...
# 22   drinkline is a confidential helpline for those...
# 23   front page world news sport business entertain...
# 24   the awardnominated comedy drama set in alcohol...
# 25   56 awardnominated comedy drama by pete jackson...
# 26   britains streets of booze monday 3  friday 7 o...
# 27   image caption addicts on the recovery programm...
# 28   as the raf marks its centenary, aled jones is ...
# 29   image copyright getty images eminem has reveal...
# ..                                                 ...
# 360  please turn on javascript. media requires java...
# 361  gibson presented the best director award at su...
# 362  image caption ministers argue law enforcement ...
# 363  a collection of some of the best reads from th...
# 364  image caption james mcdonald wrapped sophie mc...
# 365  the secret footballer thought about taking his...
# 366  image copyright pa image caption monsieur zen ...
# 367  men still drink more than women units explaine...
# 368  another new year, another list of resolutions ...
# 369  derechos de autor de la imagen hbo image capti...
# 370  image caption ruby wax has been touring the sh...
# 371  video a ukwide survey for the princes trust su...
# 372  image copyright other image caption orwells na...
# 373  by branwen jeffreys health correspondent, bbc ...
# 374  image caption bryan starred in her own bbc sho...
# 375  image caption cafodd yr achos ei glywed yn lly...
# 376  image caption exoffender jodie hind has been i...
# 377  image copyright image caption （图片来源：alamy） 所有人...
# 378  search the site cant find what you need? searc...
# 379  image copyright image caption （圖片來源：alamy） 所有人...
# 380  miss campbell will receive the high court dama...
# 381  media playback is unsupported on your device m...
# 382  mr shah was found with serious injuries outsid...
# 383  cathy macdonald talks to actress shelley king ...
# 384  hak atas foto reuters image caption produksi t...
# 385  the robert foye case fuelled concern about ope...
# 386  hmp noranside currently houses about 100 priso...
# 387  bản quyền hình ảnh getty images image capt...
# 388  according to the latest us census, detroit has...
# 389  the home office says "detention and removal ar...
#
#                                               polarity
# 0    {'neg': 0.07, 'neu': 0.851, 'pos': 0.079, 'com...
# 1    {'neg': 0.114, 'neu': 0.8, 'pos': 0.086, 'comp...
# 2    {'neg': 0.076, 'neu': 0.82, 'pos': 0.104, 'com...
# 3    {'neg': 0.112, 'neu': 0.801, 'pos': 0.087, 'co...
# 4    {'neg': 0.095, 'neu': 0.837, 'pos': 0.068, 'co...
# 5    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 6    {'neg': 0.016, 'neu': 0.924, 'pos': 0.06, 'com...
# 7    {'neg': 0.06, 'neu': 0.882, 'pos': 0.058, 'com...
# 8    {'neg': 0.0, 'neu': 0.936, 'pos': 0.064, 'comp...
# 9    {'neg': 0.0, 'neu': 0.933, 'pos': 0.067, 'comp...
# 10   {'neg': 0.106, 'neu': 0.732, 'pos': 0.162, 'co...
# 11   {'neg': 0.087, 'neu': 0.755, 'pos': 0.158, 'co...
# 12   {'neg': 0.0, 'neu': 0.75, 'pos': 0.25, 'compou...
# 13   {'neg': 0.0, 'neu': 0.8, 'pos': 0.2, 'compound...
# 14   {'neg': 0.097, 'neu': 0.736, 'pos': 0.167, 'co...
# 15   {'neg': 0.017, 'neu': 0.933, 'pos': 0.05, 'com...
# 16   {'neg': 0.112, 'neu': 0.676, 'pos': 0.213, 'co...
# 17   {'neg': 0.0, 'neu': 0.737, 'pos': 0.263, 'comp...
# 18   {'neg': 0.06, 'neu': 0.824, 'pos': 0.116, 'com...
# 19   {'neg': 0.099, 'neu': 0.764, 'pos': 0.137, 'co...
# 20   {'neg': 0.055, 'neu': 0.908, 'pos': 0.038, 'co...
# 21   {'neg': 0.176, 'neu': 0.824, 'pos': 0.0, 'comp...
# 22   {'neg': 0.057, 'neu': 0.803, 'pos': 0.14, 'com...
# 23   {'neg': 0.069, 'neu': 0.804, 'pos': 0.127, 'co...
# 24   {'neg': 0.107, 'neu': 0.733, 'pos': 0.16, 'com...
# 25   {'neg': 0.0, 'neu': 0.839, 'pos': 0.161, 'comp...
# 26   {'neg': 0.022, 'neu': 0.9, 'pos': 0.078, 'comp...
# 27   {'neg': 0.088, 'neu': 0.836, 'pos': 0.076, 'co...
# 28   {'neg': 0.039, 'neu': 0.867, 'pos': 0.094, 'co...
# 29   {'neg': 0.039, 'neu': 0.896, 'pos': 0.066, 'co...
# ..                                                 ...
# 360  {'neg': 0.086, 'neu': 0.847, 'pos': 0.067, 'co...
# 361  {'neg': 0.134, 'neu': 0.724, 'pos': 0.142, 'co...
# 362  {'neg': 0.111, 'neu': 0.824, 'pos': 0.065, 'co...
# 363  {'neg': 0.078, 'neu': 0.854, 'pos': 0.068, 'co...
# 364  {'neg': 0.123, 'neu': 0.82, 'pos': 0.057, 'com...
# 365  {'neg': 0.085, 'neu': 0.818, 'pos': 0.098, 'co...
# 366  {'neg': 0.075, 'neu': 0.845, 'pos': 0.08, 'com...
# 367  {'neg': 0.081, 'neu': 0.833, 'pos': 0.086, 'co...
# 368  {'neg': 0.041, 'neu': 0.84, 'pos': 0.118, 'com...
# 369  {'neg': 0.02, 'neu': 0.969, 'pos': 0.011, 'com...
# 370  {'neg': 0.096, 'neu': 0.788, 'pos': 0.116, 'co...
# 371  {'neg': 0.238, 'neu': 0.681, 'pos': 0.08, 'com...
# 372  {'neg': 0.115, 'neu': 0.805, 'pos': 0.08, 'com...
# 373  {'neg': 0.077, 'neu': 0.86, 'pos': 0.062, 'com...
# 374  {'neg': 0.061, 'neu': 0.802, 'pos': 0.137, 'co...
# 375  {'neg': 0.0, 'neu': 0.992, 'pos': 0.008, 'comp...
# 376  {'neg': 0.153, 'neu': 0.744, 'pos': 0.103, 'co...
# 377  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 378  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 379  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 380  {'neg': 0.057, 'neu': 0.846, 'pos': 0.097, 'co...
# 381  {'neg': 0.079, 'neu': 0.783, 'pos': 0.138, 'co...
# 382  {'neg': 0.04, 'neu': 0.786, 'pos': 0.174, 'com...
# 383  {'neg': 0.122, 'neu': 0.833, 'pos': 0.044, 'co...
# 384  {'neg': 0.0, 'neu': 0.986, 'pos': 0.014, 'comp...
# 385  {'neg': 0.163, 'neu': 0.694, 'pos': 0.144, 'co...
# 386  {'neg': 0.226, 'neu': 0.704, 'pos': 0.07, 'com...
# 387  {'neg': 0.002, 'neu': 0.996, 'pos': 0.002, 'co...
# 388  {'neg': 0.04, 'neu': 0.916, 'pos': 0.044, 'com...
# 389  {'neg': 0.079, 'neu': 0.859, 'pos': 0.062, 'co...
#
# [390 rows x 2 columns]

# %%
data.shape
# Out:
# (390, 2)
